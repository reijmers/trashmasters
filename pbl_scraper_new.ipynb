# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://www.pbl.nl/en/topics/circular-economy/publications"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

publications = soup.find_all("a", class_="node-link")


publications = [pub['href'] for pub in publications]

publications
# Out:
# ['/en/publications/integral-circular-economy-report-2023-assessment-for-the-netherlands',
#  '/en/publications/plastic-futures-and-their-co2-emissions',
#  '/en/publications/addressing-international-impacts-of-the-dutch-circular-economy-transition',
#  '/en/publications/circular-economy-progress-report-2022',
#  '/en/publications/possible-objectives-for-a-circular-economy',
#  '/en/publications/potential-effects-of-dutch-circular-economy-strategies-on-low-and-middle-income-countries',
#  '/en/publications/extended-producer-responsibility',
#  '/en/publications/potential-effects-of-dutch-circular-economy-policies-on-low-and-middle-income-countries-the-case-of-electrical-and',
#  '/en/publications/international-workshop-on-targets-for-a-circular-economy-summary',
#  '/en/publications/outline-of-the-circular-economy']

# %%
from tqdm import tqdm
url = 'https://www.pbl.nl/'

article_dicts=[]

for pub in tqdm(publications):
    response=requests.get(url+pub)
    soup = BeautifulSoup(response.text, 'html.parser')
    try:
        title = soup.find('meta', property='og:title')['content']
    except:
        title=None
    try:
        date = soup.find('span', class_='date-display-single').text.strip()
    except:
        date=None
    try:
        content=soup.find('div', class_='field field-name-field-paragraphs field-type-paragraphs field-label-hidden field--view-mode-full').text.strip()
    except:
        content=None
    try:
        introduction=soup.find('div', class_='field field-name-field-introduction-text field-type-text-long field-label-hidden field--view-mode-full').text.strip()
    except:
        introduction=None
        
    article_dict = {
        'title':title,
        'date':date,
        'introduction':introduction,
        'content':content
        
    }
    article_dicts.append(article_dict)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.03it/s]

# %%
df=pd.DataFrame(article_dicts)
df
# Out:
#                                                title        date  \
# 0  Integral Circular Economy Report 2023 Assessme...  18-04-2023
# 1            Plastic futures and their CO2 emissions  07-12-2022
# 2  Addressing international impacts of the Dutch ...  09-05-2022
# 3              Circular Economy Progress Report 2022  14-04-2022
# 4         Possible objectives for a circular economy  17-12-2021
# 5  Potential effects of Dutch circular economy st...  18-11-2021
# 6                   Extended Producer Responsibility  09-07-2021
# 7  Potential effects of Dutch circular economy st...  19-02-2021
# 8  International Workshop on Targets for a Circul...  24-02-2020
# 9                    Outline of the circular economy  29-05-2019
#
#                                         introduction  \
# 0  Every two years, the Integral Circular Economy...
# 1  A circular bioeconomy can dramatically rein in...
# 2  The Netherlands has the ambition to achieve a ...
# 3  This Circular Economy Progress Report 2022 pro...
# 4  At the request of the Dutch Ministry of Infras...
# 5  The Netherlands has the ambition to achieve a ...
# 6  Extended producer responsibility (EPR) is a wi...
# 7  The Netherlands has the ambition to achieve a ...
# 8  In preparation for The Annual World Economic F...
# 9  In many countries, governments are looking for...
#
#                                              content
# 0  The Dutch Government intends to achieve a full...
# 1                                               None
# 2  The policy brief is written at the request of ...
# 3  Update of certain indicators\nPBL will publish...
# 4  This is the English version of the summary of ...
# 5  Trade data was used to visualise trade in cott...
# 6  Effects of EPR are determined by its design\nE...
# 7  Current impacts of transboundary trade\nAround...
# 8  The workshop was attended by more than 30 lead...
# 9                                               None

# %%
df.to_csv("pbl_data.csv", index=False)

# %%
pd.read_csv('pbl_data.csv')
# Out:
#                                                title        date  \
# 0  Integral Circular Economy Report 2023 Assessme...  18-04-2023
# 1            Plastic futures and their CO2 emissions  07-12-2022
# 2  Addressing international impacts of the Dutch ...  09-05-2022
# 3              Circular Economy Progress Report 2022  14-04-2022
# 4         Possible objectives for a circular economy  17-12-2021
# 5  Potential effects of Dutch circular economy st...  18-11-2021
# 6                   Extended Producer Responsibility  09-07-2021
# 7  Potential effects of Dutch circular economy st...  19-02-2021
# 8  International Workshop on Targets for a Circul...  24-02-2020
# 9                    Outline of the circular economy  29-05-2019
#
#                                         introduction  \
# 0  Every two years, the Integral Circular Economy...
# 1  A circular bioeconomy can dramatically rein in...
# 2  The Netherlands has the ambition to achieve a ...
# 3  This Circular Economy Progress Report 2022 pro...
# 4  At the request of the Dutch Ministry of Infras...
# 5  The Netherlands has the ambition to achieve a ...
# 6  Extended producer responsibility (EPR) is a wi...
# 7  The Netherlands has the ambition to achieve a ...
# 8  In preparation for The Annual World Economic F...
# 9  In many countries, governments are looking for...
#
#                                              content
# 0  The Dutch Government intends to achieve a full...
# 1                                                NaN
# 2  The policy brief is written at the request of ...
# 3  Update of certain indicators\nPBL will publish...
# 4  This is the English version of the summary of ...
# 5  Trade data was used to visualise trade in cott...
# 6  Effects of EPR are determined by its design\nE...
# 7  Current impacts of transboundary trade\nAround...
# 8  The workshop was attended by more than 30 lead...
# 9                                                NaN
